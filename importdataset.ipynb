# %% [markdown]
# # Churn Modeling Project (Dataset Upload + Setup)
#
# ## Aim
# To upload a dataset into Google Colab and load it using Pandas for further analysis / ML.
#
# ## Tools Used
# - Google Colab
# - Python
# - Pandas

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("himanshunakrani/iris-dataset")

print("Path to dataset files:", path)

import os
os.listdir("/kaggle/input/iris-dataset")
# Out:
# Using Colab cache for faster access to the 'iris-dataset' dataset.
# Path to dataset files: /kaggle/input/iris-dataset
# ['iris.csv']

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c98a243-42d0-4460-8a31-2c6e7d634fa8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c98a243-42d0-4460-8a31-2c6e7d634fa8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import kagglehub
path = kagglehub.dataset_download("uciml/iris")
# Out:
# Using Colab cache for faster access to the 'iris' dataset.

# %% [markdown]
# ## Step 1: Mount Google Drive
# We mount Google Drive to access files stored in MyDrive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Step 2: Locate Dataset File in Drive
# Check if the dataset exists in MyDrive.

# %%
import os
os.listdir("/content/drive/MyDrive")
# Out:
# ['Colab Notebooks',
#  'PXL_20250217_055427684.MP.jpg',
#  'PXL_20250217_055435726.jpg',
#  '2 (1).jpg',
#  '2.jpg',
#  'Screenshot_20240917-163758.png',
#  'Pranav Patel(19554) 1CSE22 .pdf',
#  'IMG-20241011-WA0031.jpg',
#  'Classroom',
#  'IILM QuestionBank.gdoc',
#  'photo_2024-12-12_16-07-02.jpg',
#  'Screenshot_20250507_101916_Chrome.jpg',
#  'Student_Cumulative_Marksheet_copy.pdf',
#  'AY23-24-958170150562.pdf',
#  'Supplementary_Examination_1st_Year_(2024-2025_batch)[1].csv',
#  'IMG-20250707-WA0000.jpg',
#  'IMG-20250707-WA0001.jpg',
#  'Supplementary_Examination_1st_Year_(2024-2025_batch)[1].gsheet',
#  '1000061481.png',
#  'PRANAV_PATEL_2CSE22.pdf',
#  'photo_2025-08-25_12-03-10.jpg',
#  'Pranav.patel_2CS22.jpg',
#  'PranavPatel_2_2CSE22_2410031387.pdf',
#  'iris.csv']

# %% [markdown]
# ## Step 3: Load CSV Dataset using Pandas
# We load the dataset into a DataFrame for analysis.

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %% [markdown]
# ## Output
# - Dataset successfully loaded
# - First 5 rows displayed using `df.head()`
# - Next step: data cleaning / model training

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
